# %% [markdown]
# # Seasonal Agriculture Performance Analysis
#
# ## Major Data Analytics Project
#
# **Domain:** Agriculture
#
# **Project Theme:** Seasonal Agriculture Performance
#
# **Tools:** Python, Pandas, NumPy, Matplotlib, Seaborn
#
# ### Project Goal
#
# To investigate how agricultural performance varies across seasons
# and identify meaningful patterns, trends, relationships, and
# differences in the available data.
#
# **Important:** This is a Data Analytics project. No Machine Learning
# or dashboard development is required.

# %% [markdown]
# ## 1. Problem Statement
#
# Agricultural activities are influenced by seasonal variations in
# environmental conditions, farming practices, resource availability,
# and economic conditions. As a result, agricultural performance may
# differ from one season to another.
#
# The objective of this project is to analyze the given agricultural
# dataset and investigate seasonal differences in agricultural
# performance by identifying meaningful patterns, trends,
# relationships, and variations within the available data.
#
# The analysis will focus on understanding how agricultural
# performance changes across different seasonal conditions and
# identifying useful insights from the available data.

# %% [markdown]
# ## 2. Project Objectives
#
# The main objectives of this project are:
#
# - Understand the structure and quality of the agricultural dataset.
# - Clean and prepare the data for analysis.
# - Explore seasonal patterns in the dataset.
# - Examine agricultural performance across different seasons.
# - Perform descriptive and statistical analysis.
# - Investigate relationships among relevant variables.
# - Compare agricultural performance across seasons and other
#   meaningful groups.
# - Use appropriate univariate, bivariate, and multivariate
#   visualizations.
# - Identify significant findings from the data.
# - Develop evidence-based insights and recommendations.

# %% [markdown]
# ## 3. Key Analytical Questions
#
# The following questions will guide the analysis:
#
# 1. How does crop yield vary across different seasons?
# 2. How does agricultural production differ across seasons?
# 3. Which season has the highest average profit?
# 4. How does resource usage vary between seasons?
# 5. What relationship exists between environmental factors and crop yield?
# 6. Which crops show better agricultural performance?
# 7. Are there any unusual seasonal patterns in agricultural performance?

# %% [markdown]
# ## 4. Dataset
#
# The dataset contains farm-level agricultural records covering
# different seasons, geographical locations, crops, environmental
# conditions, farming practices, production, costs, revenue, profit,
# and resource usage.
#
# **Dataset File:** `seasonal_agriculture_performance_dataset.csv`
#
# The dataset will be analyzed to understand seasonal differences
# in agricultural performance and identify meaningful patterns and
# relationships.

# %%
# Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: f'{x:.2f}')

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
import pandas as pd

# Load the dataset

file_path = '/content/seasonal_agriculture_performance_dataset.csv'

df = pd.read_csv(file_path)

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
# Check the number of rows and columns

print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 4000
# Number of columns: 28

# %%
# Display the first 5 records

df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  Soil_pH  \
# 0       486.40              24.30         69.10                5.80     7.14
# 1       855.40              25.70         78.40                5.10     5.20
# 2       455.60              23.90         56.40               10.30     5.82
# 3       753.20              29.70         65.20                6.30     5.98
# 4       101.60              34.10         55.20                6.50     6.90
#
# ...

# %%
# Display the last 5 records

df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 3995       865.40              27.30         51.40                6.30
# 3996       947.50              29.20         85.50                6.10
# 3997        80.00              35.40         68.50                8.60
# 3998       475.00              28.20         61.70                6.40
# 3999       984.30              25.80         77.20                5.90
#
#       Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  \
# ...

# %%
# Display 5 random records

df.sample(5, random_state=42)
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 555   SF10556  Andhra Pradesh    Nashik  Chilli    Rabi                7.94
# 3491  SF13492          Punjab  Warangal   Wheat  Kharif               12.44
# 527   SF10528     Maharashtra    Indore  Cotton  Kharif                6.35
# 3925  SF13926  Madhya Pradesh    Nashik   Wheat    Rabi               12.52
# 2989  SF12990         Gujarat    Rajkot  Chilli    Rabi               13.98
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 555        456.80              25.30         47.70                7.60
# 3491       601.90              27.20         60.20                8.30
# 527       1213.70              26.30         73.60                7.10
# 3925       374.00              17.90         59.70                9.40
# 2989       197.80              19.00         55.80                9.20
#
#       Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  \
# ...

# %%
# Display all column names

print("Column Names:\n")

for i, column in \
    enumerate(df.columns, start=1):
    print(f"{i}. {column}")
# Out:
# Column Names:
#
# 1. Farm_ID
# 2. State
# 3. District
# 4. Crop
# 5. Season
# 6. Farm_Area_Hectares
# 7. Rainfall_mm
# 8. Avg_Temperature_C
# 9. Humidity_pct
# 10. Sunlight_Hours_Day
# 11. Soil_pH
# 12. Soil_Moisture_pct
# 13. Nitrogen_kg_ha
# 14. Phosphorus_kg_ha
# 15. Potassium_kg_ha
# 16. Irrigation_Method
# 17. Fertilizer_kg_ha
# 18. Pesticide_Litre_ha
# 19. Seed_Quality_Score
# 20. Yield_Tonnes_Ha
# 21. Production_Tonnes
# 22. Market_Price_INR_Tonne
# 23. Total_Cost_INR
# 24. Revenue_INR
# 25. Profit_INR
# 26. Water_Used_m3
# 27. Water_Efficiency_t_per_1000m3
# 28. Disease_Pest_Risk_pct

# %%
# Check data types and non-null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
# Check missing values in each column

missing_values = df.isnull().sum()

print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# ...

# %%
# Check for duplicate rows

duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
# Statistical summary of numerical columns

df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count             4000.00      3952.00            4000.00       4000.00
# mean                 7.89       601.15              26.82         63.21
# std                  4.22       288.93               3.82         11.96
# min                  0.50        80.00              16.20         25.00
# 25%                  4.26       370.20              23.90         54.77
# 50%                  7.89       582.00              26.90         63.00
# 75%                 11.65       834.95              29.60         71.90
# max                 15.00      1395.20              39.70         95.00
#
#        Sunlight_Hours_Day  Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count             4000.00  4000.00            3960.00         4000.00
# mean                 7.32     6.70              26.51          120.25
# std                  1.12     0.64               6.71           31.22
# ...

# %%
# Summary of categorical columns

categorical_columns = df.select_dtypes(include='object').columns

for column in categorical_columns:
    print(f"\n{column}")
    print(df[column].value_counts())
# Out:
# Farm_ID
# Farm_ID
# SF13984    1
# SF13983    1
# SF13982    1
# SF13981    1
# SF13980    1
#           ..
# SF10005    1
# SF10004    1
# SF10003    1
# SF10002    1
# SF10001    1
# Name: count, Length: 4000, dtype: int64
#
# State
# State
# Andhra Pradesh    529
# Telangana         516
# Maharashtra       512
# Madhya Pradesh    497
# Karnataka         489
# Gujarat           488
# Tamil Nadu        485
# Punjab            484
# Name: count, dtype: int64
#
# District
# District
# Ludhiana    427
# Warangal    422
# Nalgonda    415
# Erode       403
# Rajkot      401
# Krishna     393
# Indore      392
# Guntur      390
# Raichur     386
# Nashik      371
# Name: count, dtype: int64
#
# Crop
# Crop
# Rice         690
# Wheat        614
# Maize        551
# Cotton       508
# Pulses       496
# Groundnut    424
# Chilli       412
# Sugarcane    305
# Name: count, dtype: int64
#
# Season
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# ## 5. Data Cleaning
#
# Data cleaning is performed to identify and handle missing values,
# duplicate records, incorrect data types, and other data-quality
# issues before conducting further analysis.

# %%
# Missing value summary

missing_summary = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Missing Percentage': (df.isnull().sum() / len(df)) * 100
})

missing_summary = missing_summary[missing_summary['Missing Values'] > 0]

missing_summary
# Out:
#                    Missing Values  Missing Percentage
# Rainfall_mm                    48                1.20
# Soil_Moisture_pct              40                1.00
# Yield_Tonnes_Ha                32                0.80

# %%
# Fill missing numerical values using the median

df['Rainfall_mm'] = df['Rainfall_mm'].fillna(df['Rainfall_mm'].median())

df['Soil_Moisture_pct'] = df['Soil_Moisture_pct'].fillna(
    df['Soil_Moisture_pct'].median()
)

df['Yield_Tonnes_Ha'] = df['Yield_Tonnes_Ha'].fillna(
    df['Yield_Tonnes_Ha'].median()
)

print("Missing numerical values handled successfully.")
# Out:
# Missing numerical values handled successfully.

# %%
# Check missing values after cleaning

print("Total missing values:", df.isnull().sum().sum())
# Out:
# Total missing values: 0

# %%
# Display remaining missing values by column

df.isnull().sum()
# Out:
# Farm_ID                          0
# State                            0
# District                         0
# Crop                             0
# Season                           0
# Farm_Area_Hectares               0
# Rainfall_mm                      0
# Avg_Temperature_C                0
# Humidity_pct                     0
# Sunlight_Hours_Day               0
# Soil_pH                          0
# Soil_Moisture_pct                0
# Nitrogen_kg_ha                   0
# Phosphorus_kg_ha                 0
# Potassium_kg_ha                  0
# Irrigation_Method                0
# Fertilizer_kg_ha                 0
# Pesticide_Litre_ha               0
# Seed_Quality_Score               0
# Yield_Tonnes_Ha                  0
# Production_Tonnes                0
# Market_Price_INR_Tonne           0
# Total_Cost_INR                   0
# Revenue_INR                      0
# Profit_INR                       0
# Water_Used_m3                    0
# Water_Efficiency_t_per_1000m3    0
# ...

# %%
# Check duplicate records

duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
# Check data types after cleaning

df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
# Create a cleaned dataset

df_clean = df.copy()

print("Cleaned dataset created successfully.")
print("Rows:", df_clean.shape[0])
print("Columns:", df_clean.shape[1])
# Out:
# Cleaned dataset created successfully.
# Rows: 4000
# Columns: 28

# %% [markdown]
# ## 6. Exploratory Data Analysis
#
# Exploratory Data Analysis (EDA) is performed to understand the
# distribution and characteristics of the variables in the cleaned
# dataset.
#
# The analysis includes numerical summaries, categorical
# distributions, and visualizations to identify important patterns
# within the agricultural data.

# %%
# Overview of the cleaned dataset

print("Number of rows:", df_clean.shape[0])
print("Number of columns:", df_clean.shape[1])

df_clean.head()
# Out:
# Number of rows: 4000
# Number of columns: 28
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  Soil_pH  \
# 0       486.40              24.30         69.10                5.80     7.14
# 1       855.40              25.70         78.40                5.10     5.20
# 2       455.60              23.90         56.40               10.30     5.82
# 3       753.20              29.70         65.20                6.30     5.98
# 4       101.60              34.10         55.20                6.50     6.90
#
# ...

# %%
# Identify numerical columns

numerical_columns = df_clean.select_dtypes(
    include=np.number
).columns
print("Column Names:\n ")

for i, column in \
    enumerate(df.columns, start=1):
    print(f"{i}. {column}")
# Out:
# Column Names:
#
# 1. Farm_ID
# 2. State
# 3. District
# 4. Crop
# 5. Season
# 6. Farm_Area_Hectares
# 7. Rainfall_mm
# 8. Avg_Temperature_C
# 9. Humidity_pct
# 10. Sunlight_Hours_Day
# 11. Soil_pH
# 12. Soil_Moisture_pct
# 13. Nitrogen_kg_ha
# 14. Phosphorus_kg_ha
# 15. Potassium_kg_ha
# 16. Irrigation_Method
# 17. Fertilizer_kg_ha
# 18. Pesticide_Litre_ha
# 19. Seed_Quality_Score
# 20. Yield_Tonnes_Ha
# 21. Production_Tonnes
# 22. Market_Price_INR_Tonne
# 23. Total_Cost_INR
# 24. Revenue_INR
# 25. Profit_INR
# 26. Water_Used_m3
# 27. Water_Efficiency_t_per_1000m3
# 28. Disease_Pest_Risk_pct

# %%
# Identify categorical columns

categorical_columns = df_clean.select_dtypes(
    include='object'
).columns

print("Categorical columns:")
print(categorical_columns.tolist())
# Out:
# Categorical columns:
# ['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Irrigation_Method']

# %%
# Number of records in each season

season_counts = df_clean['Season'].value_counts()

print(season_counts)
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
# Visualize the number of records by season

plt.figure(figsize=(8, 5))

sns.countplot(
    data=df_clean,
    x='Season'
)

plt.title('Number of Agricultural Records by Season')
plt.xlabel('Season')
plt.ylabel('Number of Records')

plt.show()

# %%
# Count records for each crop

crop_counts = df_clean['Crop'].value_counts()

print(crop_counts)
# Out:
# Crop
# Rice         690
# Wheat        614
# Maize        551
# Cotton       508
# Pulses       496
# Groundnut    424
# Chilli       412
# Sugarcane    305
# Name: count, dtype: int64

# %%
# Visualize crop distribution

plt.figure(figsize=(10, 6))

sns.countplot(
    data=df_clean,
    y='Crop',
    order=df_clean['Crop'].value_counts().index
)

plt.title('Distribution of Agricultural Records by Crop')
plt.xlabel('Number of Records')
plt.ylabel('Crop')

plt.show()

# %%
# Count records by state

state_counts = df_clean['State'].value_counts()

print(state_counts)
# Out:
# State
# Andhra Pradesh    529
# Telangana         516
# Maharashtra       512
# Madhya Pradesh    497
# Karnataka         489
# Gujarat           488
# Tamil Nadu        485
# Punjab            484
# Name: count, dtype: int64

# %%
# Visualize records by state

plt.figure(figsize=(10, 6))

sns.countplot(
    data=df_clean,
    y='State',
    order=df_clean['State'].value_counts().index
)

plt.title('Distribution of Agricultural Records by State')
plt.xlabel('Number of Records')
plt.ylabel('State')

plt.show()

# %%
# Descriptive statistics

df_clean[numerical_columns].describe().T
# Out:
#                                 count      mean       std         min  \
# Farm_Area_Hectares            4000.00      7.89      4.22        0.50
# Rainfall_mm                   4000.00    600.92    287.19       80.00
# Avg_Temperature_C             4000.00     26.82      3.82       16.20
# Humidity_pct                  4000.00     63.21     11.96       25.00
# Sunlight_Hours_Day            4000.00      7.32      1.12        3.50
# Soil_pH                       4000.00      6.70      0.64        5.20
# Soil_Moisture_pct             4000.00     26.51      6.68        8.00
# Nitrogen_kg_ha                4000.00    120.25     31.22       40.00
# Phosphorus_kg_ha              4000.00     57.78     17.02       15.00
# Potassium_kg_ha               4000.00    104.76     27.74       30.00
# Fertilizer_kg_ha              4000.00    186.04     60.26       40.00
# Pesticide_Litre_ha            4000.00      5.07      1.98        0.50
# ...

# %% [markdown]
# ## 7. Seasonal Agriculture Performance Analysis
#
# This section analyzes agricultural performance across different
# seasons. Key agricultural, production, resource, and economic
# indicators are compared to identify seasonal differences and
# patterns.

# %%
# Check the unique seasons

print("Seasons in the dataset:")
print(df_clean['Season'].unique())
# Out:
# Seasons in the dataset:
# ['Kharif' 'Rabi' 'Zaid']

# %%
# Number of records in each season

df_clean['Season'].value_counts()
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
# Average yield by season

seasonal_yield = df_clean.groupby('Season')['Yield_Tonnes_Ha'].mean()

print("Average Yield by Season:")
print(seasonal_yield.sort_values(ascending=False))
# Out:
# Average Yield by Season:
# Season
# Kharif   5.63
# Rabi     5.04
# Zaid     4.64
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
# Average yield by season - visualization

plt.figure(figsize=(8, 5))

sns.barplot(
    data=df_clean,
    x='Season',
    y='Yield_Tonnes_Ha',
    estimator='mean'
)

plt.title('Average Crop Yield by Season')
plt.xlabel('Season')
plt.ylabel('Average Yield (Tonnes/Ha)')

plt.show()

# %%
# Average production by season

seasonal_production = df_clean.groupby('Season')['Production_Tonnes'].mean()

print("Average Production by Season:")
print(seasonal_production.sort_values(ascending=False))
# Out:
# Average Production by Season:
# Season
# Kharif   46.31
# Rabi     41.49
# Zaid     38.89
# Name: Production_Tonnes, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df_clean,
    x='Season',
    y='Production_Tonnes',
    estimator='mean'
)

plt.title('Average Agricultural Production by Season')
plt.xlabel('Season')
plt.ylabel('Average Production (Tonnes)')

plt.show()

# %%
# Average profit by season

seasonal_profit = df_clean.groupby('Season')['Profit_INR'].mean()

print("Average Profit by Season:")
print(seasonal_profit.sort_values(ascending=False))
# Out:
# Average Profit by Season:
# Season
# Kharif   178914.65
# Rabi      87689.47
# Zaid     -24804.82
# Name: Profit_INR, dtype: float64

# %%
# Visualize average profit by season

plt.figure(figsize=(8, 5))

sns.barplot(
    data=df_clean,
    x='Season',
    y='Profit_INR',
    estimator='mean'
)

plt.title('Average Agricultural Profit by Season')
plt.xlabel('Season')
plt.ylabel('Average Profit (INR)')

plt.show()

# %%
# Average revenue and cost by season

seasonal_economics = df_clean.groupby('Season')[
    ['Revenue_INR', 'Total_Cost_INR', 'Profit_INR']
].mean()

seasonal_economics
# Out:
#         Revenue_INR  Total_Cost_INR  Profit_INR
# Season
# Kharif    710719.06       531804.41   178914.65
# Rabi      601526.05       513836.58    87689.47
# Zaid      519171.90       543976.73   -24804.82

# %%
# Seasonal performance summary

seasonal_summary = df_clean.groupby('Season').agg({
    'Yield_Tonnes_Ha': 'mean',
    'Production_Tonnes': 'mean',
    'Revenue_INR': 'mean',
    'Total_Cost_INR': 'mean',
    'Profit_INR': 'mean'
}).round(2)

seasonal_summary
# Out:
#         Yield_Tonnes_Ha  Production_Tonnes  Revenue_INR  Total_Cost_INR  \
# Season
# Kharif             5.63              46.31    710719.06       531804.41
# Rabi               5.04              41.49    601526.05       513836.58
# Zaid               4.64              38.89    519171.90       543976.73
#
#         Profit_INR
# Season
# Kharif   178914.65
# Rabi      87689.47
# Zaid     -24804.82

# %% [markdown]
# ## 8. Crop Performance Analysis
#
# This section compares agricultural performance across different crops.

# %%
# Average yield by crop

crop_yield = df_clean.groupby('Crop')['Yield_Tonnes_Ha'].mean().sort_values(ascending=False)

crop_yield
# Out:
# Crop
# Sugarcane   46.64
# Maize        2.71
# Rice         2.43
# Wheat        2.11
# Chilli       1.54
# Groundnut    1.32
# Cotton       1.23
# Pulses       0.92
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(8,5))

crop_yield.plot(kind='bar')

plt.title('Average Yield by Crop')
plt.xlabel('Crop')
plt.ylabel('Average Yield (Tonnes/Ha)')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## 9. Resource Usage Analysis

# %%
# Average resource usage by season

resource_summary = df_clean.groupby('Season')[
    ['Water_Used_m3', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha']
].mean().round(2)

resource_summary
# Out:
#         Water_Used_m3  Fertilizer_kg_ha  Pesticide_Litre_ha
# Season
# Kharif        6102.20            187.08                5.08
# Rabi          5846.99            185.41                5.02
# Zaid          6419.89            184.64                5.17

# %% [markdown]
# ## 10. Environmental Analysis

# %%
# Correlation between environmental factors and yield

environmental_columns = [
    'Rainfall_mm',
    'Avg_Temperature_C',
    'Humidity_pct',
    'Sunlight_Hours_Day', # Corrected column name
    'Soil_Moisture_pct',
    'Yield_Tonnes_Ha'
]

df_clean[environmental_columns].corr()['Yield_Tonnes_Ha'].sort_values(ascending=False)
# Out:
# Yield_Tonnes_Ha       1.00
# Rainfall_mm           0.03
# Humidity_pct          0.01
# Soil_Moisture_pct     0.01
# Avg_Temperature_C     0.01
# Sunlight_Hours_Day   -0.02
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    df_clean[environmental_columns].corr(),
    annot=True,
    fmt='.2f'
)

plt.title('Correlation Between Environmental Factors and Yield')

plt.show()

# %% [markdown]
# ## 11. Key Findings
#
# The major findings from the analysis will be based on:
#
# - Seasonal differences in agricultural yield.
# - Differences in agricultural production and profit.
# - Crop-wise performance.
# - Seasonal resource usage.
# - Relationships between environmental conditions and yield.

# %% [markdown]
# ## 12. Key Findings
#
# Based on the analysis, the major observations are:
#
# - Agricultural performance varies across different seasons.
# - Crop yield differs across different crops.
# - Resource usage such as water, fertilizer, and pesticide varies across seasons.
# - Environmental factors show different levels of relationship with crop yield.
# - Seasonal differences can influence agricultural and economic performance.

# %% [markdown]
# ## 13. Recommendations
#
# Based on the analysis, the following recommendations can be made:
#
# - Agricultural planning should consider seasonal conditions.
# - Farmers should use resources efficiently according to seasonal requirements.
# - Crop selection can be planned based on seasonal performance.
# - Water and fertilizer usage should be monitored carefully.
# - Environmental conditions should be considered when planning agricultural activities.
# - Data-driven analysis can support better seasonal agricultural planning.

# %% [markdown]
# ## 14. Conclusion
#
# This project analyzed agricultural data across different seasons to
# identify patterns and differences in agricultural performance.
#
# The analysis examined crop yield, production, resource usage,
# environmental conditions, and economic performance.
#
# The results demonstrate that seasonal conditions can be associated
# with differences in agricultural performance. Data analytics and
# visualization provide useful insights that can support evidence-based
# agricultural planning and decision-making.

# %% [markdown]
# ## 15. Project Summary
#
# ### Tools Used
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
#
# ### Analysis Performed
# - Data understanding
# - Data cleaning
# - Exploratory data analysis
# - Seasonal performance analysis
# - Crop performance analysis
# - Resource usage analysis
# - Environmental analysis
# - Correlation analysis
# - Data visualization
#
# ### Outcome
#
# The project provides a focused analysis of seasonal agricultural
# performance and identifies useful patterns that can support
# evidence-based agricultural planning.
